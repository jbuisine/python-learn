# %% [markdown]
# # Matplotlib use
#
# ## Imports

# %%
import matplotlib.pyplot as plt
from matplotlib import image as mpimg
from matplotlib import gridspec
import pandas as pd
import random
import numpy as np

# %% [markdown]
# ## Display image

# %%
img = mpimg.imread('http://www.cs.us.es/~fsancho/images/2017-09/ia-imagen.png')
img.shape
# Out:
# (800, 800, 3)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Reshape image

# %%
reshapeImg = img.reshape(1000, 640, 3)
plt.imshow(reshapeImg)
plt.show()

# %% [markdown]
# ## Create RGB image

# %%
def generate_random_pixel(a, b):
    return [random.randint(a, b) for _ in range(3)]
    
img = np.array([generate_random_pixel(50, 240) for _ in range(400)])

print(img)
img = img.reshape(20, 20, 3)
img.shape
plt.imshow(img)
plt.show()
# Out:
# [[135 101  79]
#  [205 240 152]
#  [ 65  83 227]
#  ...
#  [140 123  66]
#  [124 146 155]
#  [ 69 165 117]]

# %% [markdown]
# ## Plot examples

# %%
x = np.linspace(0, 2 * np.pi)
y = np.sin(x)
plt.plot(x, y)

# %%
plt.title('Generate random numbers from a standard normal distribution with python')
plt.grid()
plt.hist(np.random.normal(100, 2, 1000), bins=10)
# Out:
# (array([  4.,  10.,  50., 159., 253., 265., 164.,  67.,  25.,   3.]),
#  array([ 92.65679744,  94.08617916,  95.51556087,  96.94494259,
#          98.3743243 ,  99.80370601, 101.23308773, 102.66246944,
#         104.09185116, 105.52123287, 106.95061459]),
#  <a list of 10 Patch objects>)
